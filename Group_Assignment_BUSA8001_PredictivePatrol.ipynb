# %% [markdown]
# ### __BUSA8001 (S2, 2023) Group Assignment - Predicting Used Car Sale Prices__

# %% [markdown]
# ---
#
# **Kaggle Competition Ends:** Friday, 3 November 2023 @ 3:00pm (Week 13)
# **Assignment Due Date on iLearn:** Friday, 3 November 2023 @ 11.59pm (Week 13)
#
# **Overview:**
#
# - In the group assignment you will form a team of 3 students and participate in a forecasting competition on Kaggle
# - The goal is to predict prices of used cars based on car characteristics and regression models
# - Assessment Summary:
#     - Write a problem statement and perform Exploratory Data Analysis
#     - Clean up data, deal with categorical features and missing observations, and create new explanatory variables (feature engineering)
#     - Construct and tune forecasting models, produce forecasts and submit your predictions to Kaggle
#     - Each member of the team will record a video presentation of their work

# %% [markdown]
# **Instructions:**
#
# - Form a team of 3 students
# - Each team member needs to join [https://www.kaggle.com](https://www.kaggle.com/)
# - Choose a team leader and form a team in the competition [https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a](https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a)
#     - Team leader to click on `team` and join and invite other 2 team members to join
#     - Your **team's name must start** with our unit code, for instance you could have a team called BUSA8001_masterful_geniuses
# - All team members should work on all the tasks however
#     - Choose a team member who will be responsible for one of each of the 3 tasks listed below
# - Your predictions must be generated by a model you develop here
#     - You will receive a mark of **zero** if your code does not produce the forecasts you submit to Kaggle

# %% [markdown]
# **Marks**:
#
# - Total Marks: 40
# - Your individual mark will consist of:
#     - 50% x overall assignment mark + 45% x mark for the task that you are responsible for + 5% x mark received from your teammates for your effort in group work
# - 1 mark: Ranking in the top 5 places of your unit on Kaggle
# - 3 marks: Reaching the first place in the competition

# %% [markdown]
# **Submissions:**
#
# 1. On Kaggle: submit your team's forecast in order to be ranked by Kaggle
#     - Limit of 20 submission per day
# 2. On iLearn **only team leader to submit** this Jupyter notebook re-named `Group_Assignment_Team_Name.ipynb` where Team_Name is your team's name on Kaggle
#     - The Jupyter notebook must contain team members names/ID numbers, and team name in the competition
#     - Provide answers to the 3 Tasks below in the allocated cells including all codes/outputs/writeups
#     - One 15 minute video recording of your work
#         - Each team member to provide a 5 minute presentation of the Task that they led (it is best to jointly record your video using Zoom)
#         - When recording your video make sure your face is visible, that you share your Jupyter Notebook and explain everything you've done in the submitted Jupyter notebook on screen
#         - 5 marks will be deducted from each Task for which there is no video presentation or if you don't follow the above instructions
#
# 3. On iLearn each student needs to submit a file with their teammates' names, ID number and a mark for their group effort (out of 100%)

# %% [markdown]
# ---

# %% [markdown]
# **Fill out the following information**
#
# For each team member provide name, Student ID number and which task is performed below

# %% [markdown]
# - Team Name on Kaggle: `(BUSA8001_PredictivePatrol)`
# - Team Leader and Team Member 1: `(Ruslan Khissamiyev - 46862528)`
# - Team Member 2: `(Tuan Minh Luu - 47695722)`
# - Team Member 3: `(Hnin Ei Shwe Yi - 46814752)`

# %% [markdown]
# ---
#
# ## Task 1: Problem Description and Initial Data Analysis
#
# 1. Read the Competition Overview on Kaggle [https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a](https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a)
# 2. Referring to Competition Overview and the data provided on Kaggle write **Problem Description** (about 500 words) focusing on key points that will need to be addressed as first steps in Tasks 2 and 3 below,
#
# - Using the following headings:
#     - Forecasting Problem - explain what you are trying to do and how it could be used in the real world (i.e. why it may be important)
#     - Evaluation Criteria - explain the criteria is used to assess forecast performance
#     - Types of Variables/Features
#     - Data summary and main data characteristics
#     - Missing Values (only explain what you find - do not impute missing values at this stage)
#     - You should **not** discuss any specific predictive algorithms at this stage
#     - Note: Your written portion of this task should be completed in a single Markdown cell
#
# Total Marks: 12

# %%
import pandas as pd

data_folder = "./busa-group-assignment-s2-2023/"

train_data = pd.read_csv(data_folder + 'train.csv')
test_data = pd.read_csv(data_folder + 'test.csv')
sample_submission = pd.read_csv(data_folder + 'sample_submission.csv')

# %%
train_data.head()
# Out:
#                  vin back_legroom        body_type          city  \
# 0  SJKCH5CRXHA032566      33.5 in  SUV / Crossover    Great Neck
# 1  5LMCJ3D96HUL54638      36.8 in  SUV / Crossover         Wayne
# 2  5LMCJ2D95HUL35217      36.8 in  SUV / Crossover         Wayne
# 3  2HGFG1B86AH500600      30.3 in            Coupe  Little Ferry
# 4  5LMCJ1D95LUL25032      38.6 in  SUV / Crossover         Wayne
#
#    city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# 0                NaN            20       11021               2000.0
# 1               19.0            64        7470               2300.0
# 2               19.0            14        7470               2300.0
# 3               25.0            13        7643               1800.0
# 4               21.0            14        7470               2000.0
#
#   engine_type                             exterior_color  ...  savings_amount  \
# 0          I4                                      Black  ...            1522
# ...

# %%
train_data.columns
# Out:
# Index(['vin', 'back_legroom', 'body_type', 'city', 'city_fuel_economy',
#        'daysonmarket', 'dealer_zip', 'engine_displacement', 'engine_type',
#        'exterior_color', 'franchise_dealer', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'height', 'highway_fuel_economy',
#        'horsepower', 'interior_color', 'is_new', 'latitude', 'length',
#        'listed_date', 'listing_color', 'longitude', 'make_name',
#        'maximum_seating', 'mileage', 'model_name', 'power', 'savings_amount',
#        'seller_rating', 'torque', 'transmission', 'transmission_display',
#        'wheel_system', 'wheelbase', 'width', 'year', 'price'],
#       dtype='object')

# %%
test_data.head()
# Out:
#                  vin back_legroom        body_type              city  \
# 0  5N1AT2MV8HC824461      37.9 in  SUV / Crossover       Wallingford
# 1  1GNSKCKC2HR160472        39 in  SUV / Crossover  North Plainfield
# 2  5NPD84LFXJH361029      35.7 in            Sedan        West Nyack
# 3  5XXGT4L34KG284916      35.6 in            Sedan             Bronx
# 4  2G1WF52E819291457          NaN            Sedan      Little Ferry
#
#    city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# 0               25.0            19        6492               2500.0
# 1               16.0            34        7060               5300.0
# 2               28.0            49       10994               2000.0
# 3               24.0            20       10466               2400.0
# 4               19.0            38        7643               3400.0
#
#             engine_type            exterior_color  ...               power  \
# ...

# %%
train_data
# Out:
#                     vin back_legroom        body_type          city  \
# 0     SJKCH5CRXHA032566      33.5 in  SUV / Crossover    Great Neck
# 1     5LMCJ3D96HUL54638      36.8 in  SUV / Crossover         Wayne
# 2     5LMCJ2D95HUL35217      36.8 in  SUV / Crossover         Wayne
# 3     2HGFG1B86AH500600      30.3 in            Coupe  Little Ferry
# 4     5LMCJ1D95LUL25032      38.6 in  SUV / Crossover         Wayne
# ...                 ...          ...              ...           ...
# 3495  KM8K1CAA4KU341682      34.6 in  SUV / Crossover   Springfield
# 3496  1FMFU16577LA61079      39.1 in  SUV / Crossover  Little Ferry
# 3497  1FMCU9J90KUB72183      37.3 in  SUV / Crossover         Holly
# 3498  2C3CDXGJ0LH121690      40.1 in            Sedan         Bronx
# 3499  5NPEF4JA9LH051412      34.8 in            Sedan      Stamford
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# 0                   NaN            20       11021               2000.0
# ...

# %% [markdown]
# ## Problem Description
#
# **Forecasting Problem:**
#
# In today's dynamic automobile market, there is no convenient way for a car's owners, purchasers and manufacturers to decide the price of the used vehicle. Our project aims at predicting used cars sale prices based on the characteristics of the car to help the stakeholders decide reasonable price.
#
# A Predictive Price Modelling tool whereby a parties can enter all the relevant details such as: back legroom (Legroom in the rear seat), body type of the car(Like Convertible, Hatchback, Sedan, etc), city (Where the car is listed), etc and the Machine Learning Model will suggest the result which includes the VIN (Vehicle Identification Number) and the Price for the cars. So that prospective car cosumers wanting to confirm they're receiving a reasonable offer for their investment, sellers benefit by aligning their pricing strategies with market dynamics, ensuring profitability while maintaining competitivenessfor their autos, and producers seeking to assess the market's likely reaction to the attributes they integrate into their vehicles.
#
# **Evaluation Criteria:** In this project, we will employ RMSD to evaluate the performance of the ***Model which we will use in the next tasks***.
#
# Root-mean-square deviation (RMSD) is a measure used to quantify the difference between two sets of data points, typically representing predicted values and observed values. In machine learning, RMSD provides an advantage as it gives a clear sense of the average magnitude of prediction errors, making it a valuable tool for assessing the accuracy and reliability of regression models.
#
# $$
# RMSD = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
# Where:
# - $N$ is the total number of observations.
# - $y_i$ is the observed value for the i-th observation.
# - $\hat{y}_i$ is the predicted value for the i-th observation.
#
# **Types of Variables/Features:** The datatype of the feature are bool, float64, int64 and object. Here we found that there are 24 variables which are object or string, 13 features are numeric and 2 features are 2 boolean variables.
#
# There are  3 types of features:
# -	Numerical variables: 'city_fuel_economy', 'engine_displacement', 'highway_fuel_economy', 'horsepower', 'latitude', 'longitude', 'mileage', 'seller_rating', 'daysonmarket', 'dealer_zip', 'savings_amount', 'year','price'.
# -	Nominal categorical variables: 'vin', 'back_legroom', 'body_type', 'city', 'engine_type','exterior_color', 'front_legroom', 'fuel_tank_volume', 'fuel_type', 'height', 'interior_color', 'length', 'listed_date', 'listing_color', 'make_name', 'maximum_seating', 'model_name', 'power', 'torque', 'transmission', 'transmission_display', 'wheel_system', 'wheelbase', 'width'.
# -	Binary categorical variables (True /False): 'franchise_dealer', 'is_new'.
#
# **Data Summary and Main Data Characteristics:** Dataset provided are divided into training data and test data separately. The training data, designed to train and validate our forecasting models, consists of 3500 entries and 39 variables (include the target ***price*** variable). while the test dataset which will be used to assess the performance of our predictive models contains 1500 observations and 38 variables. Given the sizable amount of data, it's important to approach it methodically, ensuring that we comprehend the distribution, variance, and relationships between variables.
#
# The target variable is ***price*** that we will be predicted in task 3.
#
# **Missing values:**  Missing values are a common issue in any real-world dataset. In the initial stages of data exploration, addressing missing values is paramount. Absent data can introduce unintended biases or inaccuracies in our predictive models. An early assessment will pinpoint which attributes lack complete data and the magnitude of these gaps. Depending on the nature and distribution of the missing information, diverse strategies for data imputation will be considered. It's vital to select an approach that maintains the integrity of the original dataset and doesn't skew its intrinsic patterns.

# %% [markdown]
# ---
#
# ## Task 2: Data Cleaning, Missing Observations and Feature Engineering
# - In this task you will follow a set of instructions/questions listed below.
# - Make sure you explain each answer carefully both in Markdown text and on your video.
#
# Total Marks: 12

# %% [markdown]
# **Task 2, Question 1**: Clean **all** numerical features so that they can be used in training algorithms. For instance, back_legroom feature is in object format containing both numerical values and text. Extract numerical values (equivalently eliminate the text) so that the numerical values can be used as a regular feature.
# (2 marks)

# %%
## Task 2, Question 1 Code 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Hnin Ei Shwe Yi\OneDrive\Desktop\Test applied\BUSA8001GroupProject\Group_Assignment_BUSA8001_PredictivePatrol.ipynb Cell 18 line <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hnin%20Ei%20Shwe%20Yi/OneDrive/Desktop/Test%20applied/BUSA8001GroupProject/Group_Assignment_BUSA8001_PredictivePatrol.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np # linear algebra
#       <a href='vscode-notebook-cell:/c%3A/Users/Hnin%20Ei%20Shwe%20Yi/OneDrive/Desktop/Test%20applied/BUSA8001GroupProject/Group_Assignment_BUSA8001_PredictivePatrol.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ...

# %%
import pandas as pd
import numpy as np
import re

# Helper function to extract numerical value from a string
def extract_number(val):
    if isinstance(val, str):  # Check if the value is of type string
        # Extract the number from the string using regex
        match = re.search(r'(\d+\.?\d*)', val)
        # Return the number if a match is found, otherwise return NaN
        return float(match.group(1)) if match else np.nan
    return val  # If not string, return the original value

# List of specific columns to clean
columns_to_clean = ['back_legroom', 'front_legroom', 'fuel_tank_volume', 'highway_fuel_economy',
    'horsepower', 'interior_color', 'maximum_seating', 'mileage',
    'power', 'torque', 'length', 'height', 'maximum_seating', 'wheelbase', 'width']

# Clean the specified columns in train_data dataframe
for column in columns_to_clean:
    train_data[column] = train_data[column].apply(extract_number)
    train_data[column] = pd.to_numeric(train_data[column], errors='coerce')  # This will convert invalid parsing to NaN

# Handle NaN values by filling them with the column mean
for column in columns_to_clean:
    train_data[column].fillna(train_data[column].mean(), inplace=True)

# If you have a test_data dataframe and want to clean it in the same way:
for column in columns_to_clean:
    test_data[column] = test_data[column].apply(extract_number)
    test_data[column] = pd.to_numeric(test_data[column], errors='coerce')
    test_data[column].fillna(test_data[column].mean(), inplace=True)

# %%
train_data
# Out:
#                     vin  back_legroom        body_type          city  \
# 0     SJKCH5CRXHA032566          33.5  SUV / Crossover    Great Neck
# 1     5LMCJ3D96HUL54638          36.8  SUV / Crossover         Wayne
# 2     5LMCJ2D95HUL35217          36.8  SUV / Crossover         Wayne
# 3     2HGFG1B86AH500600          30.3            Coupe  Little Ferry
# 4     5LMCJ1D95LUL25032          38.6  SUV / Crossover         Wayne
# ...                 ...           ...              ...           ...
# 3495  KM8K1CAA4KU341682          34.6  SUV / Crossover   Springfield
# 3496  1FMFU16577LA61079          39.1  SUV / Crossover  Little Ferry
# 3497  1FMCU9J90KUB72183          37.3  SUV / Crossover         Holly
# 3498  2C3CDXGJ0LH121690          40.1            Sedan         Bronx
# 3499  5NPEF4JA9LH051412          34.8            Sedan      Stamford
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %%
test_data
# Out:
#                     vin  back_legroom        body_type              city  \
# 0     5N1AT2MV8HC824461     37.900000  SUV / Crossover       Wallingford
# 1     1GNSKCKC2HR160472     39.000000  SUV / Crossover  North Plainfield
# 2     5NPD84LFXJH361029     35.700000            Sedan        West Nyack
# 3     5XXGT4L34KG284916     35.600000            Sedan             Bronx
# 4     2G1WF52E819291457     37.465273            Sedan      Little Ferry
# ...                 ...           ...              ...               ...
# 1495  WBAKF9C53CE672450     33.700000            Coupe      Little Ferry
# 1496  KL7CJLSB1LB063169     35.700000  SUV / Crossover         Bay Shore
# 1497  JTHBK1EG7C2488661     35.900000            Sedan       Wallingford
# 1498  5NPEF4JA3LH058405     34.800000            Sedan        West Nyack
# 1499  1GNKRFED6GJ185504     36.800000  SUV / Crossover  North Plainfield
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %% [markdown]
# `(Task 2, Question 1 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 2** Create at least 5 new features from the existing numerical variables which contain multiple items of information, for example you could extract maximum torque and torque rpm from the torque variable.
# (2 marks)

# %%
train_data['vehicle_size'] = train_data['length'] * train_data['width'] * train_data['height']
test_data['vehicle_size'] = train_data['length'] * train_data['width'] * train_data['height']

# %% [markdown]
# Vehicle Size: A combination of length, width, and height could give a sense of the overall size or volume of the vehicle. This could influence the vehicle's price.

# %%
train_data['car_age'] = 2023 - train_data['year']  # Assuming current year is 2023
test_data['car_age'] = 2023 - train_data['year']  # Assuming current year is 2023

# %% [markdown]
# Age of the car: Subtracting the car's year from the current year can provide the age of the car, which can be an essential factor in determining its price.

# %%
train_data['power_to_weight'] = train_data['horsepower'] / train_data['vehicle_size']
test_data['power_to_weight'] = train_data['horsepower'] / train_data['vehicle_size']

# %% [markdown]
# Power-to-Weight Ratio: This metric is often used in the automobile industry and could be derived from horsepower and vehicle_size (or if you have a weight feature, use that).

# %%
train_data['avg_fuel_economy'] = (train_data['city_fuel_economy'] + train_data['highway_fuel_economy']) / 2
test_data['avg_fuel_economy'] = (train_data['city_fuel_economy'] + train_data['highway_fuel_economy']) / 2

# %% [markdown]
# Fuel Efficiency: The city_fuel_economy and highway_fuel_economy can be averaged to get a combined fuel efficiency.

# %%
train_data['dealer_location'] = train_data['latitude'].astype(str) + "," + train_data['longitude'].astype(str)
test_data['dealer_location'] = train_data['latitude'].astype(str) + "," + train_data['longitude'].astype(str)

# %% [markdown]
# Dealer Location: Combining latitude and longitude into a single feature may capture regional differences in car pricing.

# %%
train_data
# Out:
#                     vin  back_legroom        body_type          city  \
# 0     SJKCH5CRXHA032566          33.5  SUV / Crossover    Great Neck
# 1     5LMCJ3D96HUL54638          36.8  SUV / Crossover         Wayne
# 2     5LMCJ2D95HUL35217          36.8  SUV / Crossover         Wayne
# 3     2HGFG1B86AH500600          30.3            Coupe  Little Ferry
# 4     5LMCJ1D95LUL25032          38.6  SUV / Crossover         Wayne
# ...                 ...           ...              ...           ...
# 3495  KM8K1CAA4KU341682          34.6  SUV / Crossover   Springfield
# 3496  1FMFU16577LA61079          39.1  SUV / Crossover  Little Ferry
# 3497  1FMCU9J90KUB72183          37.3  SUV / Crossover         Holly
# 3498  2C3CDXGJ0LH121690          40.1            Sedan         Bronx
# 3499  5NPEF4JA9LH051412          34.8            Sedan      Stamford
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %%
test_data
# Out:
#                     vin  back_legroom        body_type              city  \
# 0     5N1AT2MV8HC824461     37.900000  SUV / Crossover       Wallingford
# 1     1GNSKCKC2HR160472     39.000000  SUV / Crossover  North Plainfield
# 2     5NPD84LFXJH361029     35.700000            Sedan        West Nyack
# 3     5XXGT4L34KG284916     35.600000            Sedan             Bronx
# 4     2G1WF52E819291457     37.465273            Sedan      Little Ferry
# ...                 ...           ...              ...               ...
# 1495  WBAKF9C53CE672450     33.700000            Coupe      Little Ferry
# 1496  KL7CJLSB1LB063169     35.700000  SUV / Crossover         Bay Shore
# 1497  JTHBK1EG7C2488661     35.900000            Sedan       Wallingford
# 1498  5NPEF4JA3LH058405     34.800000            Sedan        West Nyack
# 1499  1GNKRFED6GJ185504     36.800000  SUV / Crossover  North Plainfield
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %% [markdown]
# Transmission Details: Combining transmission and transmission_display could give a detailed perspective on the car's transmission, which might influence the price.

# %% [markdown]
# Reasoning:
# **Vehicle Size**: Bigger cars, especially SUVs, generally tend to be priced higher due to increased material costs and perceived value.
#
# **Age of the car**: Older cars tend to depreciate in value, so knowing the age of the car can be crucial for pricing.
#
# **Power-to-Weight Ratio**: A higher power-to-weight ratio often indicates better performance, which can command a higher price. This metric is especially relevant in sports cars and high-performance vehicles.
#
# **Fuel Efficiency**: In today's market, cars with better fuel efficiency might be priced higher, especially if they achieve the efficiency without sacrificing performance. Furthermore, with increasing fuel prices and environmental concerns, fuel efficiency can be a significant factor in car buying decisions.
#
# **Dealer Location**: Pricing can vary significantly based on location due to factors such as local demand, economic conditions, and taxes. For instance, a luxury car might be priced higher in affluent areas compared to less prosperous regions.

# %% [markdown]
# `(Task 2, Question 2 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 3**: Impute missing values for all features in both the training and test datasets.
# (3 marks)

# %%
## Task 2, Question 3 Code Here

import pandas as pd

# Function to impute missing values
def impute_missing_values(df):
    for column in df.columns:
        if df[column].dtype in ['int64', 'float64']:  # If feature is numerical
            median_val = df[column].median()
            df[column].fillna(median_val, inplace=True)
        else:  # If feature is categorical or boolean
            mode_val = df[column].mode()[0]
            df[column].fillna(mode_val, inplace=True)
    return df

# Impute missing values in train_data
train_data = impute_missing_values(train_data)

# Impute missing values in test_data
test_data = impute_missing_values(test_data)

# %%
# Ensure that all missing values are imputed
# You can check if there are any missing values left
print(train_data.isnull().sum())
# Out:
# vin                     0
# back_legroom            0
# body_type               0
# city                    0
# city_fuel_economy       0
# daysonmarket            0
# dealer_zip              0
# engine_displacement     0
# engine_type             0
# exterior_color          0
# franchise_dealer        0
# front_legroom           0
# fuel_tank_volume        0
# fuel_type               0
# height                  0
# highway_fuel_economy    0
# horsepower              0
# interior_color          0
# is_new                  0
# latitude                0
# length                  0
# listed_date             0
# listing_color           0
# longitude               0
# make_name               0
# maximum_seating         0
# mileage                 0
# model_name              0
# power                   0
# savings_amount          0
# seller_rating           0
# torque                  0
# transmission            0
# transmission_display    0
# wheel_system            0
# ...

# %%
print(test_data.isnull().sum())
# Out:
# vin                     0
# back_legroom            0
# body_type               0
# city                    0
# city_fuel_economy       0
# daysonmarket            0
# dealer_zip              0
# engine_displacement     0
# engine_type             0
# exterior_color          0
# franchise_dealer        0
# front_legroom           0
# fuel_tank_volume        0
# fuel_type               0
# height                  0
# highway_fuel_economy    0
# horsepower              0
# interior_color          0
# is_new                  0
# latitude                0
# length                  0
# listed_date             0
# listing_color           0
# longitude               0
# make_name               0
# maximum_seating         0
# mileage                 0
# model_name              0
# power                   0
# savings_amount          0
# seller_rating           0
# torque                  0
# transmission            0
# transmission_display    0
# wheel_system            0
# ...

# %%
train_data
# Out:
#                     vin  back_legroom        body_type          city  \
# 0     SJKCH5CRXHA032566          33.5  SUV / Crossover    Great Neck
# 1     5LMCJ3D96HUL54638          36.8  SUV / Crossover         Wayne
# 2     5LMCJ2D95HUL35217          36.8  SUV / Crossover         Wayne
# 3     2HGFG1B86AH500600          30.3            Coupe  Little Ferry
# 4     5LMCJ1D95LUL25032          38.6  SUV / Crossover         Wayne
# ...                 ...           ...              ...           ...
# 3495  KM8K1CAA4KU341682          34.6  SUV / Crossover   Springfield
# 3496  1FMFU16577LA61079          39.1  SUV / Crossover  Little Ferry
# 3497  1FMCU9J90KUB72183          37.3  SUV / Crossover         Holly
# 3498  2C3CDXGJ0LH121690          40.1            Sedan         Bronx
# 3499  5NPEF4JA9LH051412          34.8            Sedan      Stamford
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %%
test_data
# Out:
#                     vin  back_legroom        body_type              city  \
# 0     5N1AT2MV8HC824461     37.900000  SUV / Crossover       Wallingford
# 1     1GNSKCKC2HR160472     39.000000  SUV / Crossover  North Plainfield
# 2     5NPD84LFXJH361029     35.700000            Sedan        West Nyack
# 3     5XXGT4L34KG284916     35.600000            Sedan             Bronx
# 4     2G1WF52E819291457     37.465273            Sedan      Little Ferry
# ...                 ...           ...              ...               ...
# 1495  WBAKF9C53CE672450     33.700000            Coupe      Little Ferry
# 1496  KL7CJLSB1LB063169     35.700000  SUV / Crossover         Bay Shore
# 1497  JTHBK1EG7C2488661     35.900000            Sedan       Wallingford
# 1498  5NPEF4JA3LH058405     34.800000            Sedan        West Nyack
# 1499  1GNKRFED6GJ185504     36.800000  SUV / Crossover  North Plainfield
#
#       city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# ...

# %% [markdown]
# `(Task 2, Question 3 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 4**: Encode all categorical variables appropriately as discussed in class.
#
# - Where multiple values are given for an observation encode the observation as 'other'.
# - Where a categorical feature contains more than 5 unique values, map the features into 5 most frequent values + 'other' and then encode appropriately. For instance, map colours into 5 basic colours + 'other': [red, yellow, green, blue, purple, other] and then encode.
# (2 marks)

# %%
import pandas as pd

# Function to reduce categories and encode
def reduce_and_encode(data_train, data_test, categorical_columns):
    for col in categorical_columns:
        # Handle multiple values in an observation
        data_train[col] = data_train[col].apply(lambda x: 'other' if ',' in str(x) else x)
        data_test[col] = data_test[col].apply(lambda x: 'other' if ',' in str(x) else x)
        
        # Reduce categories to top 5 + 'other'
        if data_train[col].nunique() > 5:
            # Get the top 5 most frequent categories in the training data
            top_categories = data_train[col].value_counts().index[:5]
            
            # Replace categories not in top 5 with 'other' in both training and test data
            data_train[col] = data_train[col].apply(lambda x: x if x in top_categories else 'other')
            data_test[col] = data_test[col].apply(lambda x: x if x in top_categories else 'other')
            
    # Apply one-hot encoding
    data_train = pd.get_dummies(data_train, columns=categorical_columns, prefix=categorical_columns, drop_first=True)
    data_test = pd.get_dummies(data_test, columns=categorical_columns, prefix=categorical_columns, drop_first=True)
    
    # Align train and test data
    data_train, data_test = data_train.align(data_test, join='left', axis=1, fill_value=0)
    
    return data_train, data_test

# Identify categorical columns
categorical_cols = train_data.select_dtypes(include=['object']).columns

# Reduce categories and encode
train_data_encoded, test_data_encoded = reduce_and_encode(train_data, test_data, categorical_cols)

# Check the data
print(train_data_encoded.head())
print(test_data_encoded.head())
# Out:
#    back_legroom  city_fuel_economy  daysonmarket  dealer_zip  \
# 0          33.5               21.0            20       11021
# 1          36.8               19.0            64        7470
# 2          36.8               19.0            14        7470
# 3          30.3               25.0            13        7643
# 4          38.6               21.0            14        7470
#
#    engine_displacement  franchise_dealer  front_legroom  fuel_tank_volume  \
# 0               2000.0             False           41.3              14.8
# 1               2300.0              True           42.8              15.5
# 2               2300.0              True           42.8              15.5
# 3               1800.0             False           42.6              13.2
# 4               2000.0              True           43.2              16.2
#
#    height  highway_fuel_economy  ...  transmission_M  \
# 0    60.2             28.658997  ...           False
# ...

# %%
print(train_data.head())
print(test_data.head())
# Out:
#                  vin  back_legroom        body_type   city  city_fuel_economy  \
# 0  SJKCH5CRXHA032566          33.5  SUV / Crossover  other               21.0
# 1              other          36.8  SUV / Crossover  other               19.0
# 2              other          36.8  SUV / Crossover  other               19.0
# 3              other          30.3            Coupe  other               25.0
# 4              other          38.6  SUV / Crossover  other               21.0
#
#    daysonmarket  dealer_zip  engine_displacement engine_type exterior_color  \
# 0            20       11021               2000.0          I4          Black
# 1            64        7470               2300.0          I4          other
# 2            14        7470               2300.0          I4          other
# 3            13        7643               1800.0          I4           Blue
# 4            14        7470               2000.0          I4          other
#
# ...

# %% [markdown]
# `(Task 2, Question 4 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 5**: Perform any other actions you think need to be done on the data before constructing predictive models, and clearly explain what you have done.
# (1 marks)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# Out:
# d:\anaData\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# d:\anaData\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# d:\anaData\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():

# %%
X = train_data_encoded.drop('price', axis=1)
y = train_data_encoded['price']

# %%
# Suppose 'price' is your target variable
if 'price' in train_data_encoded.columns:
    X = train_data_encoded.drop('price', axis=1)
    y = train_data_encoded['price']
    print("Target variable found and separated successfully!")
else:
    print("Target variable not found. Please check the column names and try again.")

# %% [markdown]
# `(Task 2, Question 5 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 6**: Perform exploratory data analysis to measure the relationship between the features and the target and carefully write up your findings.
# (2 marks)

# %%
# Basic information about the dataset
print(train_data_encoded.info())

# Summary statistics
print(train_data_encoded.describe())

# Check for missing values
print(train_data_encoded.isnull().sum())

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of the target variable
sns.histplot(train_data_encoded['price'], kde=True)
plt.title('Distribution of Prices')
plt.show()
# Out:
#        back_legroom  city_fuel_economy  daysonmarket    dealer_zip  \
# count   3500.000000        3500.000000   3500.000000   3500.000000
# mean      37.410542          21.545143     78.987714  11876.966857
# std        2.708437           6.863880    104.838545  10893.589741
# min        0.000000          10.000000      0.000000    922.000000
# 25%       35.700000          18.000000     17.000000   7036.000000
# 50%       37.800000          21.000000     39.500000   8812.000000
# 75%       39.000000          23.000000     82.000000  11706.000000
# max       47.500000         127.000000    698.000000  49203.000000
#
#        engine_displacement  front_legroom  fuel_tank_volume       height  \
# count          3500.000000    3500.000000       3500.000000  3500.000000
# mean           2736.714286      42.090418         18.037047    63.986299
# std            1097.386046       1.602119          4.109359     6.207608
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# List of features to plot against price
features = ['mileage', 'year', 'horsepower', 'vehicle_size']

# Creating scatter plots
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(data=train_data_encoded, x=feature, y='price')
    plt.title(f'Price vs. {feature}')
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(train_data['city_fuel_economy'], train_data['price'])
plt.title('Scatter plot of Price vs. City Fuel Economy')
plt.xlabel('City Fuel Economy')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(train_data['horsepower'], bins=50, color='lightcoral', edgecolor='black')
plt.title('Histogram of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Calculate correlation coefficient for all numerical features against price
correlation_with_price = train_data_encoded.corr()['price'].sort_values(ascending=False)
print(correlation_with_price)

# %%
from scipy.stats import ttest_ind

# Example: T-test between prices of new and used cars
new_car_prices = train_data_encoded[train_data_encoded['is_new'] == True]['price']
used_car_prices = train_data_encoded[train_data_encoded['is_new'] == False]['price']

t_stat, p_value = ttest_ind(new_car_prices, used_car_prices)
print('T-statistic:', t_stat)
print('P-value:', p_value)

# %% [markdown]
# **Back Legroom:**
#
# Majority of the cars have a back legroom around 37.41 with a standard deviation of 2.70.
# The minimum value is 0, which might be an outlier or an error in data collection since it's not feasible for a car to have 0 inches of back legroom.
#
# **City Fuel Economy:**
#
# On average, cars have a city fuel economy of around 21.54.
# However, the maximum value is 127, which is significantly higher than the mean and could be an outlier or a special type of vehicle.
#
# **Days on Market:**
#
# Cars are on the market for an average of 78.99 days.
# The standard deviation is quite high at 104.83, indicating a wide range of days on market across different listings.
#
# **Dealer Zip:**
#
# This seems to be the postal code of the dealer. It’s a categorical variable and should be treated as such in any modeling efforts.
#
# **Engine Displacement:**
#
# The engine size is on average around 2736 cc, with a standard deviation of 1097.
#
# **Front Legroom:**
#
# Similar to back legroom, most cars have around 42.09 inches of front legroom.
#
# **Fuel Tank Volume:**
#
# The average fuel tank volume is 18.03 gallons.
#
# **Height:**
#
# Cars have an average height of 63.98 inches.
#
# **Highway Fuel Economy:**
#
# The average highway fuel economy is around 28.66.
#
# **Horsepower:**
#
# On average, cars have around 242 horsepower.

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype  # Importing CategoricalDtype directly

# %%
pd.reset_option('all')  # This will reset all options to their default values
# Out:
# C:\Users\Hnin Ei Shwe Yi\AppData\Local\Temp\ipykernel_21224\1235347577.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')  # This will reset all options to their default values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_features = train_data_cleaned.select_dtypes(include=['float64', 'int64']).columns.tolist()

for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(train_data_cleaned[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()
# Out:
# d:\anaData\lib\site-packages\seaborn\_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# c:\Users\Hnin Ei Shwe Yi\OneDrive\Desktop\Test applied\BUSA8001GroupProject\Group_Assignment_BUSA8001_PredictivePatrol.ipynb Cell 68 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hnin%20Ei%20Shwe%20Yi/OneDrive/Desktop/Test%20applied/BUSA8001GroupProject/Group_Assignment_BUSA8001_PredictivePatrol.ipynb#Y152sZmlsZQ%3D%3D?line=5'>6</a> for feature in numerical_features:
# ...

# %% [markdown]
# `(Task 2, Question 6 Text Here - insert more cells as required)`

# %% [markdown]
# ---
# ## Task 3: Fit and tune a forecasting model/Submit predictions/Report score and ranking
#
# Make sure you **clearly explain each step** you do both in text and on the recoded video.
# This task must not create any additional features and has to use on the dataset constructed in Task 2.
#
# 1. Build at least 3 machine learning (ML) regression models taking into account the outcomes of Tasks 1 & 2 (Explain Carefully)
# 2. Fit the models and tune hyperparameters via cross-validation: make sure you comment and explain each step clearly
# 3. Select your best algorithm, create predictions using the test dataset, and submit your predictions on Kaggle's competition page
# 4. Provide Kaggle ranking and **score** (screenshot your best submission) and comment
# 5. Make sure your Python code works, so that a marker that can replicate your all Kaggle Score
#
# - Hint: to perform well you will need to iterate Tasks 2 and Task 3.
#
# Total Marks: 12

# %%
#Task 3 code here

# %% [markdown]
# `(Task 3 - insert more cells as required)`

# %% [markdown]
# ## Marking Criteria
#
# - Marking Rubrics
#     - Problem Description - 12 marks
#     - Data Cleaning - 12 marks
#     - Building Forecasting models - 12 marks
#     - Competition Points - 4 marks
#
#
# - To receive full marks your solutions must satisfy the following criteria:
#     - Provide Python solutions that follow the modelling methodology developed in BUSA8001
#     - Written answers explain your logic and Python code in detail, and beformulated in easy to understand full sentences
#
# ---
# ---
